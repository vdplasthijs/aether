# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys

sys.path.append("../")

# %%
import src.data_preprocessing.create_aux_data as cad
import src.data_preprocessing.data_utils as du
import src.data_preprocessing.gee_utils as gu
from src.data.base_datamodule import BaseDataModule
from src.data.butterfly_caption_builder import ButterflyCaptionBuilder
from src.data.butterfly_dataset import ButterflyDataset

# %%
BD = ButterflyDataset(modalities=["coords"], zscore_im=True, use_aux_data=True)

# %%
# BM = BaseDataModule(dataset=BD, batch_size=32, split_mode='spatial_clusters',
#                     save_split=True,
#                     filepath_split_indices_save= os.path.join(os.environ['PROJECT_ROOT'], 'data', 'splits'),
#                     filepath_split_indices_load = os.path.join(os.environ['PROJECT_ROOT'], 'data', 'splits/split_indices_s2bms_2024-08-14-1459.pth')
# )

BCB = ButterflyCaptionBuilder(
    data_dir=os.environ["PROJECT_ROOT"] + "/data",
    templates_path=os.environ["PROJECT_ROOT"] + "/data/caption_templates/butterfly.json",
)

BM = BaseDataModule(
    dataset=BD,
    batch_size=32,
    split_mode="from_file",
    filepath_split_indices_load=os.path.join(
        os.environ["PROJECT_ROOT"], "data", "splits/split_indices_s2bms_2024-08-14-1459.pth"
    ),
    caption_builder=BCB,
)

# %%
BM.caption_builder._build_from_template(template_idx=6, row=BD[1]["aux"], convert_corine_perc=True)

# %%
BM.caption_builder.random(BD[1]["aux"])

# %%
BD[1]  # ['aux']

# %%
# BM.data_train.dataset.df

BM.load_split_indices(
    os.path.join(du.get_hydra_paths()["data_dir"], "splits/split_indices_base_2025-12-16-1822.pth")
)

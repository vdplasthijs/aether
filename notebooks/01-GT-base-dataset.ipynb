# %%
# %load_ext autoreload
# %autoreload 2
import os
os.chdir('..')
os.getcwd()

# %%
from src.data.components.base_datasets import BaseButterflyDataset
import pandas as pd

# %%
dataset = BaseButterflyDataset('data/model_ready/s2bms_bioclim_lc_data.csv', mode= 'coords', target=True)
dataset[0]

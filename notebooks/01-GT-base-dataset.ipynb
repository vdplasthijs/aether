# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.data.components.butterfly_dataset import ButterflyDataset

# %%
dataset = ButterflyDataset(df_path='../data/model_ready/s2bms_presence_with_aux_data.csv', modalities= ['coords'], target=True, numericals=True)
print(dataset.dataset_name)
dataset[0]
# Out:
# Butterflies_coords
# {'eo': {'coords': tensor([56.3079, -3.2219])},
#  'target': tensor([0.3448, 0.2414, 0.2759, 0.0000, 0.3448, 0.0000, 0.0000, 0.0000, 0.0345,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.5172, 0.0000, 0.0000, 0.3103, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.4138,
#          0.3793, 0.6552, 0.0000, 0.0000, 0.3103, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0690, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1379, 0.2759]),
#  'numericals': tensor([ 8.0000e+00,  7.4000e+00,  3.7000e+01,  4.4250e+01,  1.8800e+01,
#          -8.0000e-01,  1.9600e+01,  1.1400e+01,  4.6000e+00,  1.3900e+01,
#           2.5000e+00,  7.2700e+02,  7.2000e+01,  4.4000e+01,  1.5000e+01,
#           2.0900e+02,  1.4600e+02,  1.8000e+02,  1.8600e+02,  0.0000e+00,
# ...

# %%
from src.data.base_datamodule import GeoClipDataModule

datamodule = GeoClipDataModule(df_path='../data/model_ready/s2bms_presence_with_aux_data.csv', modalities= ['coords'], target=True, numericals=True, batch_size=4)
datamodule.prepare_data()
datamodule.setup()
# Out:
# Dataset was randomly split with proportions: (0.7, 0.15, 0.15)

# %%
batch = next(iter(datamodule.train_dataloader()))

# %%
print(batch['eo']['coords'].size())
print(batch['target'].size())
# Out:
# torch.Size([4, 2])
# torch.Size([4, 62])
